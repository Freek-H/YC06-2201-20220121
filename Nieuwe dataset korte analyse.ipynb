# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('NutrientDatasetDict.json')
df.head()
# Out:
#      ID               FoodGroup                ShortDescrip  \
# 0  1001  Dairy and Egg Products          "BUTTER,WITH SALT"
# 1  1002  Dairy and Egg Products  "BUTTER,WHIPPED,WITH SALT"
# 2  1003  Dairy and Egg Products      "BUTTER OIL,ANHYDROUS"
# 3  1004  Dairy and Egg Products               "CHEESE,BLUE"
# 4  1005  Dairy and Egg Products              "CHEESE,BRICK"
#
#                         Descrip CommonName MfgName ScientificName  \
# 0              "Butter, salted"
# 1  "Butter, whipped, with salt"
# 2       "Butter oil, anhydrous"
# 3                "Cheese, blue"
# 4               "Cheese, brick"
#
#    Energy_kcal  Protein_g  Fat_g  ...  Folate_USRDA  Niacin_USRDA  \
# 0          717       0.85  81.11  ...        0.0075      0.002625
# 1          717       0.85  81.11  ...        0.0075      0.002625
# 2          876       0.28  99.48  ...        0.0000      0.000188
# 3          353      21.40  28.74  ...        0.0900      0.063500
# ...

# %%
df.describe(include='all')
# Out:
#                   ID      FoodGroup            ShortDescrip           Descrip  \
# count    8588.000000           8588                    8588              8588
# unique           NaN             25                    8584              8588
# top              NaN  Beef Products  "BABYFOOD,MEAT,BF,STR"  "Butter, salted"
# freq             NaN            946                       2                 1
# mean    15447.909408            NaN                     NaN               NaN
# std      9231.381355            NaN                     NaN               NaN
# min      1001.000000            NaN                     NaN               NaN
# 25%      8687.750000            NaN                     NaN               NaN
# 50%     14223.500000            NaN                     NaN               NaN
# 75%     20025.500000            NaN                     NaN               NaN
# max     93600.000000            NaN                     NaN               NaN
#
# ...

# %%
df[['Energy_kcal', 'Protein_g', 'Fat_g', 'Carb_g', 'Sugar_g', 'Fiber_g']].corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_3af71_row0_col0, #T_3af71_row1_col1, #T_3af71_row2_col2, #T_3af71_row3_col3, #T_3af71_row4_col4, #T_3af71_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3af71_row0_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_3af71_row0_col2 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_3af71_row0_col3 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_3af71_row0_col4 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_3af71_row0_col5 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_3af71_row1_col0, #T_3af71_row1_col3, #T_3af71_row1_col4, #T_3af71_row1_col5, #T_3af71_row3_col1, #T_3af71_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3af71_row1_col2, #T_3af71_row5_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_3af71_row2_col0 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_3af71_row2_col1 {
# ...

# %%
plt.scatter(df['Energy_kcal'], df['Fat_g'], alpha=0.05)
plt.xlabel('Energie [kcal]')
plt.ylabel('Vet [g]')
plt.show()
